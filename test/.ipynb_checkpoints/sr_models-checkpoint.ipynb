# %%
import pandas as pd
import pickle as pk
import numpy as np
from sklearn.model_selection import train_test_split
load_model_1 = pk.load(open('finalized_model_1.sav', 'rb'))

sr_workout = pd.read_csv('C:/Users/Ali Raza Qureshi/Desktop/sets and reps.csv')

# %%
def test_model():
    data = sr_workout[['age','weight','height','goal']]
    target = sr_workout['straight bench press']
    tt=[]
    count = 0
    for k in target:
        count = count + 1
        if len(str(k)) == 3:
            v = int(k * 10)
            print(v)
        else:
            v = int(k * 100)
            print(v)
        tt.append(v)
    print(count)
    target=pd.Series(np.array(tt))
    #print(target)
    data_train, data_test, target_train, target_test = train_test_split(data, target, test_size = 0.30, random_state=0)
    #print(data_train.head(2))
    #print(target_train.head(2))
    from sklearn.naive_bayes import GaussianNB
    from sklearn.metrics import accuracy_score
    model = GaussianNB()
    pred = model.fit(data[:120], target[:120]).predict(data[120:])
    #pred = model.fit(data_train,target_train).predict(data_test)
    #print("Naive-Bayes accuracy : ",accuracy_score(target_test, pred, normalize = True))
    print("Naive-Bayes accuracy : ",accuracy_score(target[120:], pred, normalize = True))

# %%
test_model()
# Out:
# 315
# 48
# 315
# 315
# 412
# 412
# 46
# 46
# 315
# 48
# 312
# 56
# 412
# 315
# 315
# 56
# 56
# 46
# 315
# 46
# 412
# 315
# 412
# 412
# 46
# 56
# 412
# 48
# 56
# 312
# 412
# 48
# 312
# 56
# 312
# 412
# 46
# 48
# 48
# 315
# 315
# 312
# 312
# 412
# 46
# 315
# 48
# 412
# 315
# 412
# 315
# 315
# 412
# 315
# 312
# 48
# 315
# 48
# 312
# 312
# 46
# 412
# 315
# 312
# 315
# 48
# 315
# 315
# 315
# 412
# 412
# 46
# 56
# 412
# 46
# 412
# 315
# 46
# 412
# 315
# 412
# 312
# 48
# 56
# 46
# 56
# 312
# 315
# 315
# 46
# 312
# 312
# 315
# 315
# 412
# 412
# 412
# 412
# 48
# 56
# 315
# 312
# 412
# 312
# 56
# 315
# 315
# 56
# 315
# 312
# 315
# 412
# 315
# 412
# 412
# 315
# 312
# 312
# 412
# 412
# 412
# 312
# 46
# 46
# 312
# 312
# 315
# 412
# 56
# 56
# 315
# 412
# 46
# 315
# 412
# 315
# 412
# 312
# 312
# 412
# 48
# 412
# 46
# 315
# 315
# 412
# 315
# 48
# 46
# 312
# 46
# 312
# 46
# 312
# 46
# 315
# 412
# 46
# 412
# 312
# 46
# 46
# 46
# 412
# 46
# 315
# 46
# 46
# 315
# 46
# 412
# 312
# 412
# 315
# 46
# 412
# 312
# 312
# 312
# 56
# 315
# 315
# 46
# 315
# 312
# 48
# 412
# 48
# 312
# 46
# 46
# 315
# 312
# 315
# 315
# 315
# 46
# 412
# 412
# 46
# 412
# 48
# 315
# 412
# 56
# 46
# 315
# 46
# 312
# 312
# 315
# 412
# 412
# 48
# 315
# 312
# 46
# 312
# 312
# 315
# 315
# 56
# 46
# 46
# 312
# 46
# 315
# 46
# 412
# 312
# 56
# 412
# 46
# 48
# 48
# 312
# 412
# 48
# 48
# 412
# 315
# 312
# 315
# 312
# 48
# 412
# 46
# 315
# 412
# 312
# 412
# 315
# 412
# 46
# 315
# 56
# 315
# 315
# 312
# 312
# 315
# 46
# 312
# 312
# 48
# 315
# 412
# 412
# 315
# 46
# 48
# 56
# 46
# 46
# 315
# 56
# 315
# 412
# 312
# 312
# 46
# 315
# 56
# 315
# 56
# 312
# 56
# 412
# 412
# 412
# 46
# 315
# 412
# 412
# 56
# 315
# 56
# 412
# 312
# 412
# 315
# 412
# 412
# 48
# 412
# 46
# 315
# 315
# 315
# 312
# 412
# 412
# 56
# 312
# 315
# 46
# 315
# 412
# 315
# 315
# 312
# 312
# 315
# 312
# 412
# 312
# 48
# 312
# 412
# 312
# 412
# 56
# 312
# 56
# 46
# 315
# 48
# 412
# 312
# 56
# 46
# 312
# 412
# 412
# 315
# 315
# 46
# 315
# 46
# 412
# 46
# 46
# 412
# 48
# 412
# 312
# 315
# 412
# 412
# 48
# 412
# 412
# 315
# 312
# 315
# 56
# 315
# 56
# 56
# 315
# 46
# 315
# 315
# 315
# 46
# 312
# 312
# 46
# 315
# 46
# 315
# 48
# 312
# 315
# 312
# 56
# 412
# 412
# 412
# 312
# 56
# 412
# 46
# 412
# 48
# 315
# 48
# 46
# 412
# 46
# 48
# 315
# 48
# 412
# 48
# 312
# 315
# 315
# 46
# 312
# 312
# 56
# 412
# 412
# 412
# 56
# 46
# 56
# 315
# 56
# 46
# 312
# 48
# 412
# 312
# 315
# 315
# 315
# 315
# 312
# 46
# 48
# 48
# 412
# 315
# 48
# 312
# 315
# 46
# 56
# 315
# 412
# 48
# 315
# 46
# 46
# 56
# 315
# 315
# 312
# 315
# 315
# 48
# 48
# 312
# 412
# 315
# 46
# 56
# 412
# 56
# 48
# 48
# 315
# 48
# 312
# 315
# 412
# 56
# 412
# 412
# 46
# 412
# 315
# 315
# 312
# 315
# 412
# 46
# 412
# 412
# 46
# 312
# 315
# 412
# 315
# 46
# 412
# 48
# 46
# 312
# 56
# 315
# 48
# 315
# 312
# 315
# 412
# 412
# 48
# 315
# 46
# 46
# 412
# 312
# 412
# 46
# 46
# 315
# 412
# 412
# 412
# 315
# 412
# 315
# 48
# 46
# 56
# 56
# 315
# 412
# 412
# 312
# 315
# 312
# 412
# 412
# 46
# 412
# 315
# 412
# 315
# 412
# 315
# 412
# 46
# 46
# 46
# 412
# 312
# 315
# 315
# 48
# 315
# 412
# 48
# 412
# 315
# 46
# 312
# 312
# 315
# 46
# 46
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-9-d08da2596b53> in <module>
# ----> 1 test_model()
#
# <ipython-input-8-4260b26f1794> in test_model()
#       5     for k in target:
#       6         if len(str(k)) == 3:
# ----> 7             v = int(k * 10)
#       8             print(v)
#       9         else:
#
# ValueError: cannot convert float NaN to integer

# %%
def predict():
    arr = np.array([22,61,5.4,1])
    pre = load_model_1.predict([arr])
    if pre < 100:
        pr_val = pre / 10
        pr_val = str(pr_val)
        sets = pr_val[1]
        reps = pr_val[3:4]
    else:
        pr_val = pre / 100
        pr_val = str(pr_val)
        sets = pr_val[1]
        reps = pr_val[3:5]
    print(pr_val)
    print("sets : {0} \nreps : {1}".format(sets, reps))

# %%
predict()
# Out:
# [4.6]
# sets : 4
# reps : 6

# %%
def test():
    data = sr_workout[['age','weight','height','goal']]
    target = sr_workout['straight bench press']
    tt=[]
    for k in target:
        if len(str(k)) == 3:
            v = int(k * 10)
        else:
            v = int(k * 100)
        tt.append(v)
    target=pd.Series(np.array(tt))
    #print(target)
    a = []
    for i in range(0,1000):
        data_train, data_test, target_train, target_test = train_test_split(data, target, test_size = 0.30, random_state=i)
        #print(data_train.head(2))
        #print(target_train.head(2))
        from sklearn.naive_bayes import GaussianNB
        from sklearn.metrics import accuracy_score
        model = GaussianNB()
        pred = model.fit(data[:120], target[:120]).predict(data[120:])
        a.append(accuracy_score(target[120:], pred, normalize = True))
        #pred = model.fit(data_train,target_train).predict(data_test)
        #print("Naive-Bayes accuracy : ",accuracy_score(target_test, pred, normalize = True))
    print(a.index(max(a)))

# %%
test()
# Out:
# 0
